# %%
# !pip install pylidc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting pylidc
#   Downloading pylidc-0.2.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting sqlalchemy>=1.1.5 (from pylidc)
#   Downloading sqlalchemy-2.0.42-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: numpy>=1.12.0 in /home/luotingzhuang/.local/lib/python3.10/site-packages (from pylidc) (1.26.4)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from pylidc) (1.10.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pylidc) (3.7.1)
# Requirement already satisfied: pydicom>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pylidc) (2.4.4)
# Requirement already satisfied: scikit-image>=0.13 in /usr/local/lib/python3.10/dist-packages (from pylidc) (0.24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pylidc) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pylidc) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pylidc) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pylidc) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pylidc) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pylidc) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pylidc) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/luotingzhuang/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->pylidc) (2.9.0.post0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.13->pylidc) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.13->pylidc) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.13->pylidc) (2024.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.13->pylidc) (0.4)
# Collecting greenlet>=1 (from sqlalchemy>=1.1.5->pylidc)
#   Downloading greenlet-3.2.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.1.5->pylidc) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pylidc) (1.16.0)
# Downloading pylidc-0.2.3-py2.py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 5.9 MB/s eta 0:00:00a 0:00:01
# Downloading sqlalchemy-2.0.42-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 5.6 MB/s eta 0:00:00a 0:00:01m
# Downloading greenlet-3.2.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (582 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.2/582.2 kB 7.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: greenlet, sqlalchemy, pylidc
# Successfully installed greenlet-3.2.3 pylidc-0.2.3 sqlalchemy-2.0.42
#
# [notice] A new release of pip is available: 23.3.2 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip

# %% [markdown]
# # Obtain LIDC Semantic Features and Nodule Coord

# %%
import pandas as pd
import os
import pylidc as pl
from tqdm import tqdm
import numpy as np
np.int = int

# %%
def get_anno(patient_id):
    anno_df = []
    keys_to_include = ['id','scan_id','_nodule_id', 'internalStructure', 
                              'sphericity', 'lobulation', 'texture', 'subtlety', 
                              'calcification', 'margin', 'spiculation', 'malignancy']
    scans = pl.query(pl.Scan).filter(pl.Scan.patient_id == patient_id).all()
    for scan in scans:
        annotations = scan.cluster_annotations()
        for anno_id , annos in enumerate(annotations):
            for anno in annos:
                anno_dict = {key: anno.__dict__[key] for key in keys_to_include}
                anno_dict = pd.DataFrame(anno_dict, index = [0])
                anno_dict['diameter'] = anno.diameter
                anno_dict['pid'] = patient_id
                anno_dict[['x','y','z']] = anno.centroid
                anno_dict['study_instance_uid'] = scan.study_instance_uid
                anno_dict['series_instance_uid'] = scan.series_instance_uid
                anno_dict['nodule_id'] = anno_id
                anno_df.append(anno_dict)
    return anno_df

# %%
cases = ['LIDC-IDRI-0001','LIDC-IDRI-0002']
r = [get_anno(c) for c in cases]

# %%
# aggregate annotation from radiologists
anno_df = pd.concat([pd.concat(r_i) for r_i in r if r_i]).reset_index(drop = True).drop_duplicates()
keys = ['sphericity','lobulation', 'texture',  'margin', 'spiculation', 'malignancy','diameter','x','y','z']
agg_dict = {i: 'median' for i in keys}
agg_dict['internalStructure'] = pd.Series.mode
agg_dict['calcification'] = pd.Series.mode
anno_df_coord = anno_df.groupby(['pid','nodule_id']).agg(agg_dict).reset_index()
anno_df_coord
# Out:
#               pid  nodule_id  sphericity  lobulation  texture  margin  \
# 0  LIDC-IDRI-0001          0         3.5         3.0      5.0     3.5
# 1  LIDC-IDRI-0002          0         4.0         1.0      1.5     1.5
#
#    spiculation  malignancy   diameter           x           y           z  \
# 0          4.5         5.0  32.697290  366.729124  316.205336   89.639908
# 1          1.0         4.5  30.781671  361.162287  345.222282  185.044542
#
#    internalStructure  calcification
# 0                  1              6
# 1                  1              6

# %% [markdown]
# # Map to UCLA Semantic Features

# %%
cyst_like_spaces = []
for i in anno_df_coord.internalStructure:
    if isinstance(i,int):
        if i == 4:
            cyst_like_spaces.append('Present')
        else:
            cyst_like_spaces.append('Absent')
    else:
        if '4' in i:
            cyst_like_spaces.append('Present')
        else:
            cyst_like_spaces.append('Absent')
anno_df_coord['cyst_like_spaces'] = cyst_like_spaces

# %%
eccentric_calcification = []
for i in anno_df_coord.calcification:
    if isinstance(i,np.int):
        if i == 4:
            eccentric_calcification.append('Present')
        else:
            eccentric_calcification.append('Absent')
    else:
        if '4' in i:
            eccentric_calcification.append('Present')
        else:
            eccentric_calcification.append('Absent')
anno_df_coord['eccentric_calcification'] = eccentric_calcification

# %%
anno_df_coord['nodule_shape'] = ['Round' if i>3 else 'Ovoid' for  i in anno_df_coord.sphericity]
anno_df_coord['nodule_margin_conspicuity'] = ['Well marginated' if i>=3 else 'Poorly marginated' for  i in anno_df_coord.margin]
anno_df_coord['nodule_margins'] = np.nan
anno_df_coord.loc[anno_df_coord.lobulation>=3 , 'nodule_margins'] = 'Lobulated'
anno_df_coord['additional_nodule_margins'] = np.nan
anno_df_coord.loc[anno_df_coord.spiculation>=3 , 'additional_nodule_margins'] = 'Spiculated'
anno_df_coord['nodule_consistency'] = 'Part-solid'
anno_df_coord.loc[anno_df_coord.texture<2 , 'nodule_consistency'] = 'Pure ground glass'
anno_df_coord.loc[anno_df_coord.texture>4 , 'nodule_consistency'] = 'Solid'

# %%
anno_df_coord
# Out:
#               pid  nodule_id  sphericity  lobulation  texture  margin  \
# 0  LIDC-IDRI-0001          0         3.5         3.0      5.0     3.5
# 1  LIDC-IDRI-0002          0         4.0         1.0      1.5     1.5
#
#    spiculation  malignancy   diameter           x  ...           z  \
# 0          4.5         5.0  32.697290  366.729124  ...   89.639908
# 1          1.0         4.5  30.781671  361.162287  ...  185.044542
#
#    internalStructure  calcification  cyst_like_spaces eccentric_calcification  \
# 0                  1              6            Absent                  Absent
# 1                  1              6            Absent                  Absent
#
#   nodule_shape nodule_margin_conspicuity nodule_margins  \
# 0        Round           Well marginated      Lobulated
# 1        Round         Poorly marginated            NaN
#
#   additional_nodule_margins nodule_consistency
# 0                Spiculated              Solid
# 1                       NaN  Pure ground glass
#
# [2 rows x 21 columns]
